# %% [markdown]
# <a href="https://colab.research.google.com/github/Yami6575/MachineLearningFundaments/blob/main/object_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread("dog.jpg")
newImg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %% [markdown]
# # New section

# %%
plt.imshow(newImg)
plt.axis("off")
plt.show()
